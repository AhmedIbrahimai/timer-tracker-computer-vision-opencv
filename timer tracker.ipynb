# %%
import cv2
import mediapipe as mp
import time
# Settings
maximum_time = 15 # Seconds
# Load Face Detector
face_detection = mp.solutions.face_detection.FaceDetection()
# Take frame from capera
cap = cv2.VideoCapture(0)
# Track TIME
starting_time = time.time()

while True:
    # Take frame from camera
    ret, frame = cap.read()
    height , width , C  = frame.shape
    # Display frame
    #cv2.imshow("Frame", frame)
    # Face Detection
    results = face_detection.process(frame)
   
    # Is the face DETECTED?
    if results.detections:
           print("Face looking at the screen")
            
    # Is the face DETECTED?
    if results.detections:
        elapsed_time = int(time.time() - starting_time)
        if elapsed_time > maximum_time:
            # Reached maximum time, show alert
            cv2.rectangle(frame, (0, 0), (width, height), (0, 0, 225), 10)
            cv2.setWindowProperty("Frame", cv2.WND_PROP_TOPMOST, 1)
        # Draw elapsed time on screen
        cv2.putText(frame, "{} seconds".format(elapsed_time), (10, 50), cv2.FONT_HERSHEY_PLAIN,
                    3, (255, 0, 215), 2)
        print("Elapsed: {}".format(elapsed_time))
        print("Face looking at the screen")
    else:
        print("NO FACE")
        # Reset the counter
        starting_time = time.time()
    # Display frame
    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1)
    if key == 27:
        break
cv2.waitKey()
cv2.destroyAllWindows()
cap.release()
# Out:
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 0
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 1
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 2
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 3
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 4
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 5
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 6
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 7
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 8
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 9
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 10
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 11
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 12
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 13
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 14
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 15
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 16
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 17
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 18
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 19
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 20
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 21
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 22
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 23
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# Face looking at the screen
# Face looking at the screen
# Elapsed: 24
# ...
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 29
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 30
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 31
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 32
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 33
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 34
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 35
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# Elapsed: 36
# Face looking at the screen
# Face looking at the screen
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_125500\3718650018.py in <module>
#      30             # Reached maximum time, show alert
#      31             cv2.rectangle(frame, (0, 0), (width, height), (0, 0, 225), 10)
# ---> 32             cv2.setWindowProperty("Frame", cv2.WND_PROP_TOPMOST, 1)
#      33         # Draw elapsed time on screen
#      34         cv2.putText(frame, "{} seconds".format(elapsed_time), (10, 50), cv2.FONT_HERSHEY_PLAIN,
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:677: error: (-27:Null pointer) NULL window in function 'cvSetPropTopmost_W32'
